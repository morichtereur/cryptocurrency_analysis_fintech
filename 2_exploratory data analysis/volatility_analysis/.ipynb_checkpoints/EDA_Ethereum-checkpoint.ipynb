# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# %%
# Define the file path. Adjust the username and path to match your local environment.
file_path = '/Users/moritzrichter/Desktop/cryptocurrency_analysis_fintech/data/Ethereum_(ETH)/ethereum(fiveyears).csv'

# Load the dataset from the specified file path
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to ensure it has loaded correctly
df.head()
# Out:
#        Name        Date       High        Low       Open      Close  \
# 0  Ethereum  2024-04-14  3297.6372  2874.4010  3231.1639  3024.3586
# 1  Ethereum  2024-04-13  3559.2980  3207.7090  3515.9494  3245.0984
# 2  Ethereum  2024-04-12  3619.6398  3487.4192  3544.0727  3516.6996
# 3  Ethereum  2024-04-11  3559.9659  3426.2983  3505.5251  3547.5273
# 4  Ethereum  2024-04-10  3719.8724  3480.2572  3702.1783  3510.2155
#
#          Volume     Marketcap
# 0  3.279679e+10  3.842367e+11
# 1  2.059745e+10  4.132227e+11
# 2  2.335933e+10  4.258414e+11
# 3  2.549431e+10  4.218612e+11
# 4  2.741439e+10  4.328726e+11

# %%
# Convert 'Date' to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Sorting the DataFrame by the 'Date' column in ascending order
df_sorted = df.sort_values(by='Date', ascending=True)

print(df_sorted)
# Out:
#           Name       Date         High          Low         Open        Close  \
# 1824  Ethereum 2019-04-17   169.793896   162.671355   163.085245   169.793896
# 1823  Ethereum 2019-04-18   170.759335   167.288903   169.485605   168.445130
# 1822  Ethereum 2019-04-19   176.325867   168.036023   168.402685   174.767110
# 1821  Ethereum 2019-04-20   175.010126   171.873865   174.901697   174.800910
# 1820  Ethereum 2019-04-21   177.250340   173.480841   174.860856   175.282926
# ...        ...        ...          ...          ...          ...          ...
# 4     Ethereum 2024-04-10  3719.872400  3480.257200  3702.178300  3510.215500
# 3     Ethereum 2024-04-11  3559.965900  3426.298300  3505.525100  3547.527300
# 2     Ethereum 2024-04-12  3619.639800  3487.419200  3544.072700  3516.699600
# 1     Ethereum 2024-04-13  3559.298000  3207.709000  3515.949400  3245.098400
# 0     Ethereum 2024-04-14  3297.637200  2874.401000  3231.163900  3024.358600
#
#             Volume     Marketcap
# 1824  4.349636e+09  1.747363e+10
# 1823  4.252172e+09  1.779057e+10
# 1822  4.994551e+09  1.833714e+10
# 1821  5.053026e+09  1.838350e+10
# 1820  4.891869e+09  1.851742e+10
# ...            ...           ...
# 4     2.741439e+10  4.328726e+11
# 3     2.549431e+10  4.218612e+11
# 2     2.335933e+10  4.258414e+11
# 1     2.059745e+10  4.132227e+11
# 0     3.279679e+10  3.842367e+11
#
# [1825 rows x 8 columns]

# %%
df_sorted.tail()
# Out:
#        Name       Date       High        Low       Open      Close  \
# 4  Ethereum 2024-04-10  3719.8724  3480.2572  3702.1783  3510.2155
# 3  Ethereum 2024-04-11  3559.9659  3426.2983  3505.5251  3547.5273
# 2  Ethereum 2024-04-12  3619.6398  3487.4192  3544.0727  3516.6996
# 1  Ethereum 2024-04-13  3559.2980  3207.7090  3515.9494  3245.0984
# 0  Ethereum 2024-04-14  3297.6372  2874.4010  3231.1639  3024.3586
#
#          Volume     Marketcap
# 4  2.741439e+10  4.328726e+11
# 3  2.549431e+10  4.218612e+11
# 2  2.335933e+10  4.258414e+11
# 1  2.059745e+10  4.132227e+11
# 0  3.279679e+10  3.842367e+11

# %%
df_sorted.shape
# Out:
# (1825, 8)

# %%
# Check for null values in the Close column
df_sorted["Close"].isnull().values.any()
# Out:
# False

# %%
# Visualize the close price over time
ax = df_sorted.plot(x='Date', y='Close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Ethereum")
# Out:
# Text(0.5, 1.0, 'Close Price of Ethereum')

# %% [markdown]
# # Examine the volatility for the year 2023

# %%
# Filter the dates for the year 2023
start_date = "2023-01-01"
end_date = "2023-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2023 = df_sorted.loc[between_two_dates]

print(year_2023)
# Out:
#          Name       Date         High          Low         Open        Close  \
# 469  Ethereum 2023-01-01  1207.241600  1194.981085  1200.644747  1197.487800
# 468  Ethereum 2023-01-02  1205.095800  1193.422200  1197.144400  1201.562297
# 467  Ethereum 2023-01-03  1220.937600  1195.771838  1201.323435  1214.525803
# 466  Ethereum 2023-01-04  1220.072800  1207.850703  1214.772991  1214.986593
# 465  Ethereum 2023-01-05  1266.162448  1213.680037  1214.943900  1257.048427
# ..        ...        ...          ...          ...          ...          ...
# 109  Ethereum 2023-12-27  2280.534200  2196.648000  2277.846300  2236.053000
# 108  Ethereum 2023-12-28  2392.224300  2220.107800  2234.910600  2382.921900
# 107  Ethereum 2023-12-29  2447.600900  2344.325000  2389.603200  2354.309600
# 106  Ethereum 2023-12-30  2389.672900  2278.696300  2355.203100  2304.586800
# 105  Ethereum 2023-12-31  2330.236100  2279.869600  2302.385100  2307.432900
#
#            Volume     Marketcap
# 469  7.761570e+09  1.468131e+11
# 468  6.431232e+09  1.466334e+11
# 467  7.972082e+09  1.483785e+11
# 466  8.335575e+09  1.486179e+11
# 465  1.308554e+10  1.528305e+11
# ..            ...           ...
# 109  1.223844e+10  2.697093e+11
# 108  1.488911e+10  2.758120e+11
# 107  2.203663e+10  2.871123e+11
# 106  1.809633e+10  2.816557e+11
# 105  1.396335e+10  2.771907e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2023
df_2023 = pd.DataFrame(data=year_2023)
df_2023.head()
# Out:
#          Name       Date         High          Low         Open        Close  \
# 469  Ethereum 2023-01-01  1207.241600  1194.981085  1200.644747  1197.487800
# 468  Ethereum 2023-01-02  1205.095800  1193.422200  1197.144400  1201.562297
# 467  Ethereum 2023-01-03  1220.937600  1195.771838  1201.323435  1214.525803
# 466  Ethereum 2023-01-04  1220.072800  1207.850703  1214.772991  1214.986593
# 465  Ethereum 2023-01-05  1266.162448  1213.680037  1214.943900  1257.048427
#
#            Volume     Marketcap
# 469  7.761570e+09  1.468131e+11
# 468  6.431232e+09  1.466334e+11
# 467  7.972082e+09  1.483785e+11
# 466  8.335575e+09  1.486179e+11
# 465  1.308554e+10  1.528305e+11

# %%
# Visualize the Ethereum close price for 2023
ax = df_2023.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Ethereum in 2023")
# Out:
# Text(0.5, 1.0, 'Close Price of Ethereum in 2023')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2023["Log_Returns"] = np.log(df_2023['Close']/df_2023['Close'].shift())
df_2023.head()
# Out:
#          Name       Date         High          Low         Open        Close  \
# 469  Ethereum 2023-01-01  1207.241600  1194.981085  1200.644747  1197.487800
# 468  Ethereum 2023-01-02  1205.095800  1193.422200  1197.144400  1201.562297
# 467  Ethereum 2023-01-03  1220.937600  1195.771838  1201.323435  1214.525803
# 466  Ethereum 2023-01-04  1220.072800  1207.850703  1214.772991  1214.986593
# 465  Ethereum 2023-01-05  1266.162448  1213.680037  1214.943900  1257.048427
#
#            Volume     Marketcap  Log_Returns
# 469  7.761570e+09  1.468131e+11          NaN
# 468  6.431232e+09  1.466334e+11     0.003397
# 467  7.972082e+09  1.483785e+11     0.010731
# 466  8.335575e+09  1.486179e+11     0.000379
# 465  1.308554e+10  1.528305e+11     0.034033

# %%
# We need the std deviation for the volatility of the stock
# df_2023["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year. Square root = **.5
volatility_2023 = df_2023["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2023 stock price of Ethereum
str_vol_2023 = str(round(volatility_2023, 4)*100)

print(str_vol_2023)
# Out:
# 45.89

# %%
# Visualize the volatility of the 2023 stock price of Ethereum

fig, ax = plt.subplots()
df_2023["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2023 Ethereum Volatility: " + str_vol_2023 + "%" )
# Out:
# Text(0.5, 1.0, '2023 Ethereum Volatility: 45.89%')

# %% [markdown]
# # Examine the volatility for the year 2022

# %%
# Filter the dates for the year 2022
start_date = "2022-01-01"
end_date = "2022-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2022 = df_sorted.loc[between_two_dates]

print(year_2022)
# Out:
#          Name       Date         High          Low         Open        Close  \
# 834  Ethereum 2022-01-01  3821.726100  3644.590367  3721.875500  3691.611156
# 833  Ethereum 2022-01-02  3785.075067  3685.986363  3685.986363  3773.583400
# 832  Ethereum 2022-01-03  3850.080300  3738.107600  3777.230300  3839.813900
# 831  Ethereum 2022-01-04  3847.977500  3701.319266  3838.539500  3770.231700
# 830  Ethereum 2022-01-05  3888.932141  3731.840156  3771.472600  3797.755382
# ..        ...        ...          ...          ...          ...          ...
# 474  Ethereum 2022-12-27  1227.656046  1214.129722  1219.770522  1227.656046
# 473  Ethereum 2022-12-28  1231.436679  1205.191200  1228.551574  1212.875706
# 472  Ethereum 2022-12-29  1214.267850  1185.751800  1212.821120  1190.811142
# 471  Ethereum 2022-12-30  1205.254315  1188.558000  1190.805154  1202.142956
# 470  Ethereum 2022-12-31  1202.737159  1186.317400  1201.761285  1199.671997
#
#            Volume     Marketcap
# 834  1.684483e+10  4.460166e+11
# 833  1.583896e+10  4.451427e+11
# 832  1.208173e+10  4.499025e+11
# 831  1.638377e+10  4.520520e+11
# 830  2.187737e+10  4.524619e+11
# ..            ...           ...
# 474  9.316884e+09  1.492606e+11
# 473  9.369368e+09  1.490749e+11
# 472  1.193488e+10  1.465753e+11
# 471  1.198224e+10  1.465822e+11
# 470  1.007265e+10  1.463803e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2022
df_2022 = pd.DataFrame(data=year_2022)
df_2022.head()
# Out:
#          Name       Date         High          Low         Open        Close  \
# 834  Ethereum 2022-01-01  3821.726100  3644.590367  3721.875500  3691.611156
# 833  Ethereum 2022-01-02  3785.075067  3685.986363  3685.986363  3773.583400
# 832  Ethereum 2022-01-03  3850.080300  3738.107600  3777.230300  3839.813900
# 831  Ethereum 2022-01-04  3847.977500  3701.319266  3838.539500  3770.231700
# 830  Ethereum 2022-01-05  3888.932141  3731.840156  3771.472600  3797.755382
#
#            Volume     Marketcap
# 834  1.684483e+10  4.460166e+11
# 833  1.583896e+10  4.451427e+11
# 832  1.208173e+10  4.499025e+11
# 831  1.638377e+10  4.520520e+11
# 830  2.187737e+10  4.524619e+11

# %%
# Visualize the Ethereum close price for 2022
ax = df_2022.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Ethereum in 2022")
# Out:
# Text(0.5, 1.0, 'Close Price of Ethereum in 2022')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2022["Log_Returns"] = np.log(df_2022['Close']/df_2022['Close'].shift())
df_2022.head()
# Out:
#          Name       Date         High          Low         Open        Close  \
# 834  Ethereum 2022-01-01  3821.726100  3644.590367  3721.875500  3691.611156
# 833  Ethereum 2022-01-02  3785.075067  3685.986363  3685.986363  3773.583400
# 832  Ethereum 2022-01-03  3850.080300  3738.107600  3777.230300  3839.813900
# 831  Ethereum 2022-01-04  3847.977500  3701.319266  3838.539500  3770.231700
# 830  Ethereum 2022-01-05  3888.932141  3731.840156  3771.472600  3797.755382
#
#            Volume     Marketcap  Log_Returns
# 834  1.684483e+10  4.460166e+11          NaN
# 833  1.583896e+10  4.451427e+11     0.021962
# 832  1.208173e+10  4.499025e+11     0.017399
# 831  1.638377e+10  4.520520e+11    -0.018287
# 830  2.187737e+10  4.524619e+11     0.007274

# %%
# We need the std deviation for the volatility of the stock
# df_2022["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year. Square root = **.5
volatility_2022 = df_2022["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2022 stock price of Ethereum
str_vol_2022 = str(round(volatility_2022, 3)*100)

print(str_vol_2022)
# Out:
# 87.7

# %%
# Visualize the volatility of the 2022 stock price of Ethereum

fig, ax = plt.subplots()
df_2022["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2022 Ethereum Volatility: " + str_vol_2022 + "%" )
# Out:
# Text(0.5, 1.0, '2022 Ethereum Volatility: 87.7%')

# %% [markdown]
# # Examine the volatility for the year 2021

# %%
# Filter the dates for the year 2021
start_date = "2021-01-01"
end_date = "2021-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2021 = df_sorted.loc[between_two_dates]

print(year_2021)
# Out:
#           Name       Date         High          Low         Open        Close  \
# 1199  Ethereum 2021-01-01   756.931006   730.761952   753.304157   744.037439
# 1198  Ethereum 2021-01-02   754.297612   722.419457   743.134660   730.868534
# 1197  Ethereum 2021-01-03   786.291987   718.063089   731.435388   771.806381
# 1196  Ethereum 2021-01-04  1008.359353   771.135300   771.219259   982.082463
# 1195  Ethereum 2021-01-05  1152.226308   916.755033   976.801807  1040.789197
# ...        ...        ...          ...          ...          ...          ...
# 839   Ethereum 2021-12-27  4105.350600  4020.062200  4099.685282  4076.411442
# 838   Ethereum 2021-12-28  4128.638300  4042.103900  4071.642379  4044.835106
# 837   Ethereum 2021-12-29  4044.256508  3788.353454  4044.256508  3814.279700
# 836   Ethereum 2021-12-30  3836.195189  3634.019303  3808.748900  3639.101876
# 835   Ethereum 2021-12-31  3774.378774  3620.622805  3640.373261  3724.106300
#
#             Volume     Marketcap
# 1199  3.208592e+10  8.495193e+10
# 1198  2.370683e+10  8.436999e+10
# 1197  2.203531e+10  8.552753e+10
# 1196  4.243752e+10  9.793298e+10
# 1195  9.991489e+10  1.155654e+11
# ...            ...           ...
# 839   1.490555e+10  4.828357e+11
# 838   1.406808e+10  4.851309e+11
# 837   1.960572e+10  4.643036e+11
# 836   2.050396e+10  4.502630e+11
# 835   2.360372e+10  4.419016e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2021
df_2021 = pd.DataFrame(data=year_2021)
df_2021.head()
# Out:
#           Name       Date         High         Low        Open        Close  \
# 1199  Ethereum 2021-01-01   756.931006  730.761952  753.304157   744.037439
# 1198  Ethereum 2021-01-02   754.297612  722.419457  743.134660   730.868534
# 1197  Ethereum 2021-01-03   786.291987  718.063089  731.435388   771.806381
# 1196  Ethereum 2021-01-04  1008.359353  771.135300  771.219259   982.082463
# 1195  Ethereum 2021-01-05  1152.226308  916.755033  976.801807  1040.789197
#
#             Volume     Marketcap
# 1199  3.208592e+10  8.495193e+10
# 1198  2.370683e+10  8.436999e+10
# 1197  2.203531e+10  8.552753e+10
# 1196  4.243752e+10  9.793298e+10
# 1195  9.991489e+10  1.155654e+11

# %%
# Visualize the Ethereum close price for 2021
ax = df_2021.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Ethereum in 2021")
# Out:
# Text(0.5, 1.0, 'Close Price of Ethereum in 2021')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2021["Log_Returns"] = np.log(df_2021['Close']/df_2021['Close'].shift())
df_2021.head()
# Out:
#           Name       Date         High         Low        Open        Close  \
# 1199  Ethereum 2021-01-01   756.931006  730.761952  753.304157   744.037439
# 1198  Ethereum 2021-01-02   754.297612  722.419457  743.134660   730.868534
# 1197  Ethereum 2021-01-03   786.291987  718.063089  731.435388   771.806381
# 1196  Ethereum 2021-01-04  1008.359353  771.135300  771.219259   982.082463
# 1195  Ethereum 2021-01-05  1152.226308  916.755033  976.801807  1040.789197
#
#             Volume     Marketcap  Log_Returns
# 1199  3.208592e+10  8.495193e+10          NaN
# 1198  2.370683e+10  8.436999e+10    -0.017858
# 1197  2.203531e+10  8.552753e+10     0.054500
# 1196  4.243752e+10  9.793298e+10     0.240942
# 1195  9.991489e+10  1.155654e+11     0.058059

# %%
# We need the std deviation for the volatility of the stock
# df_2021["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year. Square root = **.5
volatility_2021 = df_2021["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2021 stock price of Ethereum
str_vol_2021 = str(round(volatility_2021, 2)*100)

print(str_vol_2021)
# Out:
# 106.0

# %%
# Visualize the volatility of the 2021 stock price of Ethereum

fig, ax = plt.subplots()
df_2021["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2021 Ethereum Volatility: " + str_vol_2021 + "%" )
# Out:
# Text(0.5, 1.0, '2021 Ethereum Volatility: 106.0%')

# %%
# Overlay the close price for 2021-2023

x1 = df_2021["Date"]
x2 = df_2022["Date"]
x3 = df_2023["Date"]

a = df_2021["Close"].values
b = df_2022["Close"].values
c = df_2023["Close"].values


plt.plot(x1, a, label= "2021" )
plt.plot(x2, b, label= "2022" )
plt.plot(x3, c, label= "2023" )

plt.title("Close Price of Ethereum (2021-2023) ")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.legend()
plt.show()

# %%
# Visualize the volatility percent as a bar chart
# plt.bar(x, height, width, bottom, align)

year = ["2021", "2022", "2023"]
values = [float(str_vol_2021), float(str_vol_2022), float(str_vol_2023)]

colors = ["blue", "orange", "green"]

fig = plt.figure(figsize = (8, 5))
 
# creating the bar plot
plt.bar(x=year, height=values, color=colors, edgecolor='black', width = 0.4, bottom=0)
 
plt.xlabel("Year")
plt.ylabel("Percent Volatility")
plt.title("Annual Percent Volatility of Ethereum (2021-2023) ")
plt.show()
