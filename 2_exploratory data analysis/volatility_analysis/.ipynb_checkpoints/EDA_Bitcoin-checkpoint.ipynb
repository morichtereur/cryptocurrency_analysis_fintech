# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# %%
# Define the file path. Adjust the username and path to match your local environment.
file_path = '/Users/moritzrichter/Desktop/cryptocurrency_analysis_fintech/data/Bitcoin_(BTC)/bitcoin(fiveyears).csv'

# Load the dataset from the specified file path
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to ensure it has loaded correctly
df.head()
# Out:
#       Name        Date      High       Low      Open     Close        Volume  \
# 0  Bitcoin  2024-04-14  67890.08  61480.00  67033.18  64255.94  1.707821e+11
# 1  Bitcoin  2024-04-13  71173.45  66012.76  70120.03  67208.21  1.564710e+11
# 2  Bitcoin  2024-04-12  71247.81  69587.99  70436.71  70112.05  1.634891e+11
# 3  Bitcoin  2024-04-11  71078.17  67590.15  69125.17  70513.60  1.588973e+11
# 4  Bitcoin  2024-04-10  71714.42  68442.77  71618.12  69198.22  1.324055e+11
#
#       Marketcap
# 0  1.309283e+12
# 1  1.367866e+12
# 2  1.386264e+12
# 3  1.361469e+12
# 4  1.380411e+12

# %%
# Convert 'Date' to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Sorting the DataFrame by the 'Date' column in ascending order
df_sorted = df.sort_values(by='Date', ascending=True)

print(df_sorted)
# Out:
#          Name       Date          High           Low          Open  \
# 1824  Bitcoin 2019-04-17   5285.269355   5083.122626   5110.364743
# 1823  Bitcoin 2019-04-18   5309.767053   5247.411896   5274.409619
# 1822  Bitcoin 2019-04-19   5330.747550   5268.381876   5271.352176
# 1821  Bitcoin 2019-04-20   5349.185233   5253.519639   5308.334719
# 1820  Bitcoin 2019-04-21   5372.559483   5314.995062   5318.985321
# ...       ...        ...           ...           ...           ...
# 4     Bitcoin 2024-04-10  71714.420000  68442.770000  71618.120000
# 3     Bitcoin 2024-04-11  71078.170000  67590.150000  69125.170000
# 2     Bitcoin 2024-04-12  71247.810000  69587.990000  70436.710000
# 1     Bitcoin 2024-04-13  71173.450000  66012.760000  70120.030000
# 0     Bitcoin 2024-04-14  67890.080000  61480.000000  67033.180000
#
#              Close        Volume     Marketcap
# 1824   5280.621478  1.122892e+10  9.101929e+10
# 1823   5271.109695  1.171812e+10  9.299844e+10
# 1822   5309.256996  1.106357e+10  9.346719e+10
# 1821   5317.962150  1.072242e+10  9.345605e+10
# 1820   5363.756655  1.208157e+10  9.440771e+10
# ...            ...           ...           ...
# 4     69198.220000  1.324055e+11  1.380411e+12
# 3     70513.600000  1.588973e+11  1.361469e+12
# 2     70112.050000  1.634891e+11  1.386264e+12
# 1     67208.210000  1.564710e+11  1.367866e+12
# 0     64255.940000  1.707821e+11  1.309283e+12
#
# [1825 rows x 8 columns]

# %%
df_sorted.tail()
# Out:
#       Name       Date      High       Low      Open     Close        Volume  \
# 4  Bitcoin 2024-04-10  71714.42  68442.77  71618.12  69198.22  1.324055e+11
# 3  Bitcoin 2024-04-11  71078.17  67590.15  69125.17  70513.60  1.588973e+11
# 2  Bitcoin 2024-04-12  71247.81  69587.99  70436.71  70112.05  1.634891e+11
# 1  Bitcoin 2024-04-13  71173.45  66012.76  70120.03  67208.21  1.564710e+11
# 0  Bitcoin 2024-04-14  67890.08  61480.00  67033.18  64255.94  1.707821e+11
#
#       Marketcap
# 4  1.380411e+12
# 3  1.361469e+12
# 2  1.386264e+12
# 1  1.367866e+12
# 0  1.309283e+12

# %%
df_sorted.shape
# Out:
# (1825, 8)

# %%
# Check for null values in the Close column
df_sorted["Close"].isnull().values.any()
# Out:
# False

# %%
# Visualize the close price over time
ax = df_sorted.plot(x='Date', y='Close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Bitcoin")
# Out:
# Text(0.5, 1.0, 'Close Price of Bitcoin')

# %% [markdown]
# # Examine the volatility for the year 2023

# %%
# Filter the dates for the year 2020
start_date = "2023-01-01"
end_date = "2023-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2023 = df_sorted.loc[between_two_dates]

print(year_2023)
# Out:
#         Name       Date          High           Low          Open  \
# 469  Bitcoin 2023-01-01  16632.899700  16495.873732  16608.070868
# 468  Bitcoin 2023-01-02  16621.165100  16507.390600  16537.454200
# 467  Bitcoin 2023-01-03  16758.525308  16560.090732  16617.254396
# 466  Bitcoin 2023-01-04  16763.447292  16616.632381  16673.748747
# 465  Bitcoin 2023-01-05  16973.381191  16658.433945  16674.508700
# ..       ...        ...           ...           ...           ...
# 109  Bitcoin 2023-12-27  43573.220000  41723.240000  43573.220000
# 108  Bitcoin 2023-12-28  43624.640000  42154.050000  42484.060000
# 107  Bitcoin 2023-12-29  43730.030000  42321.070000  43421.730000
# 106  Bitcoin 2023-12-30  43033.780000  41683.160000  42631.140000
# 105  Bitcoin 2023-12-31  42570.010000  41539.760000  42040.120000
#
#             Close        Volume     Marketcap
# 469  16538.347900  3.406534e+10  3.183907e+11
# 468  16607.069459  2.350878e+10  3.181669e+11
# 467  16677.449944  2.485967e+10  3.207060e+11
# 466  16675.909037  2.964833e+10  3.207174e+11
# 465  16857.282709  3.938416e+10  3.233862e+11
# ..            ...           ...           ...
# 109  42519.800000  3.219680e+10  8.363471e+11
# 108  43384.250000  3.368300e+10  8.385209e+11
# 107  42592.060000  3.533272e+10  8.405227e+11
# 106  42057.410000  3.525232e+10  8.305440e+11
# 105  42198.850000  3.475819e+10  8.247402e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2023
df_2023 = pd.DataFrame(data=year_2023)
df_2023.head()
# Out:
#         Name       Date          High           Low          Open  \
# 469  Bitcoin 2023-01-01  16632.899700  16495.873732  16608.070868
# 468  Bitcoin 2023-01-02  16621.165100  16507.390600  16537.454200
# 467  Bitcoin 2023-01-03  16758.525308  16560.090732  16617.254396
# 466  Bitcoin 2023-01-04  16763.447292  16616.632381  16673.748747
# 465  Bitcoin 2023-01-05  16973.381191  16658.433945  16674.508700
#
#             Close        Volume     Marketcap
# 469  16538.347900  3.406534e+10  3.183907e+11
# 468  16607.069459  2.350878e+10  3.181669e+11
# 467  16677.449944  2.485967e+10  3.207060e+11
# 466  16675.909037  2.964833e+10  3.207174e+11
# 465  16857.282709  3.938416e+10  3.233862e+11

# %%
# Visualize the Bitcoin close price for 2023
ax = df_2023.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Bitcoin in 2023")
# Out:
# Text(0.5, 1.0, 'Close Price of Bitcoin in 2023')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2023["Log_Returns"] = np.log(df_2023['Close']/df_2023['Close'].shift())
df_2023.head()
# Out:
#         Name       Date          High           Low          Open  \
# 469  Bitcoin 2023-01-01  16632.899700  16495.873732  16608.070868
# 468  Bitcoin 2023-01-02  16621.165100  16507.390600  16537.454200
# 467  Bitcoin 2023-01-03  16758.525308  16560.090732  16617.254396
# 466  Bitcoin 2023-01-04  16763.447292  16616.632381  16673.748747
# 465  Bitcoin 2023-01-05  16973.381191  16658.433945  16674.508700
#
#             Close        Volume     Marketcap  Log_Returns
# 469  16538.347900  3.406534e+10  3.183907e+11          NaN
# 468  16607.069459  2.350878e+10  3.181669e+11     0.004147
# 467  16677.449944  2.485967e+10  3.207060e+11     0.004229
# 466  16675.909037  2.964833e+10  3.207174e+11    -0.000092
# 465  16857.282709  3.938416e+10  3.233862e+11     0.010818

# %%
# We need the std deviation for the volatility of the stock
# df_2023["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year for crypto. Square root = **.5
volatility_2023 = df_2023["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2023 stock price of Bitcoin
str_vol_2023 = str(round(volatility_2023, 4)*100)

print(str_vol_2023)
# Out:
# 43.37

# %%
# Visualize the volatility of the 2023 stock price of Bitcoin

fig, ax = plt.subplots()
df_2023["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2023 Bitcoin Volatility: " + str_vol_2023 + "%" )
# Out:
# Text(0.5, 1.0, '2023 Bitcoin Volatility: 43.37%')

# %% [markdown]
# # Examine the volatility for the year 2022

# %%
# Filter the dates for the year 2022
start_date = "2022-01-01"
end_date = "2022-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2022 = df_sorted.loc[between_two_dates]

print(year_2022)
# Out:
#         Name       Date          High           Low          Open  \
# 834  Bitcoin 2022-01-01  48505.999700  45712.566592  47139.359000
# 833  Bitcoin 2022-01-02  47840.310785  46198.203781  46198.203781
# 832  Bitcoin 2022-01-03  47869.110700  46702.753900  47722.939700
# 831  Bitcoin 2022-01-04  47514.360018  45703.028075  47311.946700
# 830  Bitcoin 2022-01-05  47493.993100  45705.038988  46412.079600
# ..       ...        ...           ...           ...           ...
# 474  Bitcoin 2022-12-27  16911.649971  16804.839787  16832.923371
# 473  Bitcoin 2022-12-28  16963.002980  16631.430000  16919.823027
# 472  Bitcoin 2022-12-29  16762.014600  16488.762900  16706.249402
# 471  Bitcoin 2022-12-30  16655.070278  16503.195500  16547.534921
# 470  Bitcoin 2022-12-31  16639.843547  16379.532500  16636.993115
#
#             Close        Volume     Marketcap
# 834  46304.949594  7.810027e+10  8.945653e+11
# 833  47544.499400  9.941362e+10  8.911811e+11
# 832  47313.632200  7.453585e+10  8.936273e+11
# 831  46424.346000  1.159970e+11  8.857233e+11
# 830  45884.459658  7.467415e+10  8.784294e+11
# ..            ...           ...           ...
# 474  16908.948430  2.654351e+10  3.237754e+11
# 473  16706.459710  3.144405e+10  3.229231e+11
# 472  16549.983266  3.860298e+10  3.197136e+11
# 471  16641.444864  4.178537e+10  3.188295e+11
# 470  16603.751953  3.645157e+10  3.180110e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2022
df_2022 = pd.DataFrame(data=year_2022)
df_2022.head()
# Out:
#         Name       Date          High           Low          Open  \
# 834  Bitcoin 2022-01-01  48505.999700  45712.566592  47139.359000
# 833  Bitcoin 2022-01-02  47840.310785  46198.203781  46198.203781
# 832  Bitcoin 2022-01-03  47869.110700  46702.753900  47722.939700
# 831  Bitcoin 2022-01-04  47514.360018  45703.028075  47311.946700
# 830  Bitcoin 2022-01-05  47493.993100  45705.038988  46412.079600
#
#             Close        Volume     Marketcap
# 834  46304.949594  7.810027e+10  8.945653e+11
# 833  47544.499400  9.941362e+10  8.911811e+11
# 832  47313.632200  7.453585e+10  8.936273e+11
# 831  46424.346000  1.159970e+11  8.857233e+11
# 830  45884.459658  7.467415e+10  8.784294e+11

# %%
# Visualize the Bitcoin close price for 2022
ax = df_2022.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Bitcoin in 2022")
# Out:
# Text(0.5, 1.0, 'Close Price of Bitcoin in 2022')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2022["Log_Returns"] = np.log(df_2022['Close']/df_2022['Close'].shift())
df_2022.head()
# Out:
#         Name       Date          High           Low          Open  \
# 834  Bitcoin 2022-01-01  48505.999700  45712.566592  47139.359000
# 833  Bitcoin 2022-01-02  47840.310785  46198.203781  46198.203781
# 832  Bitcoin 2022-01-03  47869.110700  46702.753900  47722.939700
# 831  Bitcoin 2022-01-04  47514.360018  45703.028075  47311.946700
# 830  Bitcoin 2022-01-05  47493.993100  45705.038988  46412.079600
#
#             Close        Volume     Marketcap  Log_Returns
# 834  46304.949594  7.810027e+10  8.945653e+11          NaN
# 833  47544.499400  9.941362e+10  8.911811e+11     0.026417
# 832  47313.632200  7.453585e+10  8.936273e+11    -0.004868
# 831  46424.346000  1.159970e+11  8.857233e+11    -0.018974
# 830  45884.459658  7.467415e+10  8.784294e+11    -0.011698

# %%
# We need the std deviation for the volatility of the stock
# df_2022["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year. Square root = **.5
volatility_2022 = df_2022["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2022 stock price of Bitcoin
str_vol_2022 = str(round(volatility_2022, 3)*100)

print(str_vol_2022)
# Out:
# 65.0

# %%
# Visualize the volatility of the 2022 stock price of Bitcoin

fig, ax = plt.subplots()
df_2022["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2022 Bitcoin Volatility: " + str_vol_2022 + "%" )
# Out:
# Text(0.5, 1.0, '2022 Bitcoin Volatility: 65.0%')

# %% [markdown]
# # Examine the volatility for the year 2021

# %%
# Filter the dates for the year 2021
start_date = "2021-01-01"
end_date = "2021-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2021 = df_sorted.loc[between_two_dates]

print(year_2021)
# Out:
#          Name       Date          High           Low          Open  \
# 1199  Bitcoin 2021-01-01  29272.578049  27986.652153  28863.191666
# 1198  Bitcoin 2021-01-02  29560.027546  28718.621788  28938.896888
# 1197  Bitcoin 2021-01-03  33158.612438  29014.295884  29329.695772
# 1196  Bitcoin 2021-01-04  34717.662742  32057.582963  32148.048500
# 1195  Bitcoin 2021-01-05  33553.450548  29066.665438  32949.399464
# ...       ...        ...           ...           ...           ...
# 839   Bitcoin 2021-12-27  51209.462718  49545.532097  50390.389286
# 838   Bitcoin 2021-12-28  51950.912600  50459.263641  50787.263830
# 837   Bitcoin 2021-12-29  50667.988338  47411.717237  50667.988338
# 836   Bitcoin 2021-12-30  48112.021472  46272.662981  47547.865500
# 835   Bitcoin 2021-12-31  47876.491839  46077.722276  46430.481224
#
#              Close        Volume     Marketcap
# 1199  28977.961818  7.927135e+10  5.363150e+11
# 1198  29300.190936  6.455859e+10  5.429904e+11
# 1197  32093.264962  7.010424e+10  5.704312e+11
# 1196  32877.607283  1.243495e+11  6.217950e+11
# 1195  31973.832154  1.309183e+11  5.918035e+11
# ...            ...           ...           ...
# 839   50799.978861  4.267183e+10  9.482650e+11
# 838   50650.171445  4.695844e+10  9.655866e+11
# 837   47637.888400  5.939821e+10  9.241336e+11
# 836   46408.302671  8.826973e+10  8.998872e+11
# 835   47161.009200  1.229248e+11  8.907742e+11
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2021
df_2021 = pd.DataFrame(data=year_2021)
df_2021.head()
# Out:
#          Name       Date          High           Low          Open  \
# 1199  Bitcoin 2021-01-01  29272.578049  27986.652153  28863.191666
# 1198  Bitcoin 2021-01-02  29560.027546  28718.621788  28938.896888
# 1197  Bitcoin 2021-01-03  33158.612438  29014.295884  29329.695772
# 1196  Bitcoin 2021-01-04  34717.662742  32057.582963  32148.048500
# 1195  Bitcoin 2021-01-05  33553.450548  29066.665438  32949.399464
#
#              Close        Volume     Marketcap
# 1199  28977.961818  7.927135e+10  5.363150e+11
# 1198  29300.190936  6.455859e+10  5.429904e+11
# 1197  32093.264962  7.010424e+10  5.704312e+11
# 1196  32877.607283  1.243495e+11  6.217950e+11
# 1195  31973.832154  1.309183e+11  5.918035e+11

# %%
# Visualize the Bitcoin close price for 2021
ax = df_2021.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Bitcoin in 2021")
# Out:
# Text(0.5, 1.0, 'Close Price of Bitcoin in 2021')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2021["Log_Returns"] = np.log(df_2021['Close']/df_2021['Close'].shift())
df_2021.head()
# Out:
#          Name       Date          High           Low          Open  \
# 1199  Bitcoin 2021-01-01  29272.578049  27986.652153  28863.191666
# 1198  Bitcoin 2021-01-02  29560.027546  28718.621788  28938.896888
# 1197  Bitcoin 2021-01-03  33158.612438  29014.295884  29329.695772
# 1196  Bitcoin 2021-01-04  34717.662742  32057.582963  32148.048500
# 1195  Bitcoin 2021-01-05  33553.450548  29066.665438  32949.399464
#
#              Close        Volume     Marketcap  Log_Returns
# 1199  28977.961818  7.927135e+10  5.363150e+11          NaN
# 1198  29300.190936  6.455859e+10  5.429904e+11     0.011058
# 1197  32093.264962  7.010424e+10  5.704312e+11     0.091052
# 1196  32877.607283  1.243495e+11  6.217950e+11     0.024146
# 1195  31973.832154  1.309183e+11  5.918035e+11    -0.027874

# %%
# We need the std deviation for the volatility of the stock
# df_2021["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~365 trading days per year. Square root = **.5
volatility_2021 = df_2021["Log_Returns"].std()*365**.5

# %%
# Calculate the volatility of the 2021 stock price of Bitcoin
str_vol_2021 = str(round(volatility_2021, 2)*100)

print(str_vol_2021)
# Out:
# 80.0

# %%
# Visualize the volatility of the 2021 stock price of Bitcoin

fig, ax = plt.subplots()
df_2021["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2021 Bitcoin Volatility: " + str_vol_2021 + "%" )
# Out:
# Text(0.5, 1.0, '2021 Bitcoin Volatility: 80.0%')

# %%
# Overlay the close price for 2021-2023

x1 = df_2021["Date"]
x2 = df_2022["Date"]
x3 = df_2023["Date"]

a = df_2021["Close"].values
b = df_2022["Close"].values
c = df_2023["Close"].values


plt.plot(x1, a, label= "2021" )
plt.plot(x2, b, label= "2022" )
plt.plot(x3, c, label= "2023" )

plt.title("Close Price of Bitcoin (2021-2023) ")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.legend()
plt.show()

# %%
# Visualize the volatility percent as a bar chart
# plt.bar(x, height, width, bottom, align)

year = ["2021", "2022", "2023"]
values = [float(str_vol_2021), float(str_vol_2022), float(str_vol_2023)]

colors = ["blue", "orange", "green"]

fig = plt.figure(figsize = (8, 5))
 
# creating the bar plot
plt.bar(x=year, height=values, color=colors, edgecolor='black', width = 0.4, bottom=0)
 
plt.xlabel("Year")
plt.ylabel("Percent Volatility")
plt.title("Annual Percent Volatility of Bitcoin (2021-2023) ")
plt.show()
