# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# %%
# Define the file path. Adjust the username and path to match your local environment.
file_path = '/Users/moritzrichter/Desktop/cryptocurrency_analysis/data/Cardano_(ADA)/cardano(fiveyears).csv'

# Load the dataset from the specified file path
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to ensure it has loaded correctly
df.head()
# Out:
#       Name        Date      High       Low      Open     Close        Volume  \
# 0  Cardano  2024-04-14  0.515976  0.403025  0.500729  0.448884  2.069858e+09
# 1  Cardano  2024-04-13  0.592644  0.469921  0.587957  0.503170  9.016875e+08
# 2  Cardano  2024-04-12  0.594598  0.576771  0.585616  0.587021  7.408927e+08
# 3  Cardano  2024-04-11  0.593858  0.563156  0.591030  0.586004  8.980409e+08
# 4  Cardano  2024-04-10  0.623052  0.591227  0.614145  0.592833  7.793677e+08
#
#       Marketcap
# 0  1.742501e+10
# 1  1.989046e+10
# 2  2.087529e+10
# 3  2.067740e+10
# 4  2.157853e+10

# %%
# Convert 'Date' to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Sorting the DataFrame by the 'Date' column in ascending order
df_sorted = df.sort_values(by='Date', ascending=True)

print(df_sorted)
# Out:
#          Name       Date      High       Low      Open     Close  \
# 1824  Cardano 2019-04-17  0.084724  0.081028  0.083096  0.084645
# 1823  Cardano 2019-04-18  0.084992  0.082735  0.084550  0.083647
# 1822  Cardano 2019-04-19  0.084465  0.081675  0.083719  0.082058
# 1821  Cardano 2019-04-20  0.082082  0.078741  0.082082  0.079886
# 1820  Cardano 2019-04-21  0.079887  0.075924  0.079821  0.076902
# ...       ...        ...       ...       ...       ...       ...
# 4     Cardano 2024-04-10  0.623052  0.591227  0.614145  0.592833
# 3     Cardano 2024-04-11  0.593858  0.563156  0.591030  0.586004
# 2     Cardano 2024-04-12  0.594598  0.576771  0.585616  0.587021
# 1     Cardano 2024-04-13  0.592644  0.469921  0.587957  0.503170
# 0     Cardano 2024-04-14  0.515976  0.403025  0.500729  0.448884
#
#             Volume     Marketcap
# 1824  1.009852e+08  2.153132e+09
# 1823  9.266402e+07  2.169354e+09
# 1822  9.340067e+07  2.158388e+09
# 1821  1.144789e+08  2.066557e+09
# 1820  1.060710e+08  2.024528e+09
# ...            ...           ...
# 4     7.793677e+08  2.157853e+10
# 3     8.980409e+08  2.067740e+10
# 2     7.408927e+08  2.087529e+10
# 1     9.016875e+08  1.989046e+10
# 0     2.069858e+09  1.742501e+10
#
# [1825 rows x 8 columns]

# %%
df_sorted.tail()
# Out:
#       Name       Date      High       Low      Open     Close        Volume  \
# 4  Cardano 2024-04-10  0.623052  0.591227  0.614145  0.592833  7.793677e+08
# 3  Cardano 2024-04-11  0.593858  0.563156  0.591030  0.586004  8.980409e+08
# 2  Cardano 2024-04-12  0.594598  0.576771  0.585616  0.587021  7.408927e+08
# 1  Cardano 2024-04-13  0.592644  0.469921  0.587957  0.503170  9.016875e+08
# 0  Cardano 2024-04-14  0.515976  0.403025  0.500729  0.448884  2.069858e+09
#
#       Marketcap
# 4  2.157853e+10
# 3  2.067740e+10
# 2  2.087529e+10
# 1  1.989046e+10
# 0  1.742501e+10

# %%
df_sorted.shape
# Out:
# (1825, 8)

# %%
# Check for null values in the Close column
df_sorted["Close"].isnull().values.any()
# Out:
# False

# %%
# Visualize the close price over time
ax = df_sorted.plot(x='Date', y='Close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Cardano")
# Out:
# Text(0.5, 1.0, 'Close Price of Cardano')

# %% [markdown]
# # Examine the volatility for the year 2023

# %%
# Filter the dates for the year 2023
start_date = "2023-01-01"
end_date = "2023-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2023 = df_sorted.loc[between_two_dates]

print(year_2023)
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 469  Cardano 2023-01-01  0.251705  0.244255  0.245672  0.245946  3.708277e+08
# 468  Cardano 2023-01-02  0.249741  0.244054  0.245744  0.249556  2.865892e+08
# 467  Cardano 2023-01-03  0.255774  0.247491  0.249900  0.253456  3.001893e+08
# 466  Cardano 2023-01-04  0.255106  0.250347  0.253643  0.252894  2.963426e+08
# 465  Cardano 2023-01-05  0.269472  0.252146  0.252814  0.267587  4.912787e+08
# ..       ...        ...       ...       ...       ...       ...           ...
# 109  Cardano 2023-12-27  0.627432  0.578437  0.627432  0.609035  1.200747e+09
# 108  Cardano 2023-12-28  0.642310  0.587200  0.607101  0.633738  1.443987e+09
# 107  Cardano 2023-12-29  0.675133  0.611026  0.633977  0.617088  2.001058e+09
# 106  Cardano 2023-12-30  0.624839  0.597741  0.618701  0.608241  1.449057e+09
# 105  Cardano 2023-12-31  0.612404  0.594184  0.607526  0.601838  8.369768e+08
#
#         Marketcap
# 469  8.344051e+09
# 468  8.333257e+09
# 467  8.548079e+09
# 466  8.552052e+09
# 465  8.932257e+09
# ..            ...
# 109  2.057851e+10
# 108  2.077411e+10
# 107  2.159312e+10
# 106  2.069607e+10
# 105  2.046442e+10
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2023
df_2023 = pd.DataFrame(data=year_2023)
df_2023.head()
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 469  Cardano 2023-01-01  0.251705  0.244255  0.245672  0.245946  3.708277e+08
# 468  Cardano 2023-01-02  0.249741  0.244054  0.245744  0.249556  2.865892e+08
# 467  Cardano 2023-01-03  0.255774  0.247491  0.249900  0.253456  3.001893e+08
# 466  Cardano 2023-01-04  0.255106  0.250347  0.253643  0.252894  2.963426e+08
# 465  Cardano 2023-01-05  0.269472  0.252146  0.252814  0.267587  4.912787e+08
#
#         Marketcap
# 469  8.344051e+09
# 468  8.333257e+09
# 467  8.548079e+09
# 466  8.552052e+09
# 465  8.932257e+09

# %%
# Visualize the Cardano close price for 2023
ax = df_2023.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Cardano in 2023")
# Out:
# Text(0.5, 1.0, 'Close Price of Cardano in 2023')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2023["Log_Returns"] = np.log(df_2023['Close']/df_2023['Close'].shift())
df_2023.head()
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 469  Cardano 2023-01-01  0.251705  0.244255  0.245672  0.245946  3.708277e+08
# 468  Cardano 2023-01-02  0.249741  0.244054  0.245744  0.249556  2.865892e+08
# 467  Cardano 2023-01-03  0.255774  0.247491  0.249900  0.253456  3.001893e+08
# 466  Cardano 2023-01-04  0.255106  0.250347  0.253643  0.252894  2.963426e+08
# 465  Cardano 2023-01-05  0.269472  0.252146  0.252814  0.267587  4.912787e+08
#
#         Marketcap  Log_Returns
# 469  8.344051e+09          NaN
# 468  8.333257e+09     0.014573
# 467  8.548079e+09     0.015508
# 466  8.552052e+09    -0.002221
# 465  8.932257e+09     0.056473

# %%
# We need the std deviation for the volatility of the stock
# df_2023["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2023 = df_2023["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2023 stock price of Cardano
str_vol_2023 = str(round(volatility_2023, 4)*100)

print(str_vol_2023)
# Out:
# 55.1

# %%
# Visualize the volatility of the 2023 stock price of Cardano

fig, ax = plt.subplots()
df_2023["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2023 Cardano Volatility: " + str_vol_2023 + "%" )
# Out:
# Text(0.5, 1.0, '2023 Cardano Volatility: 55.1%')

# %% [markdown]
# # Examine the volatility for the year 2022

# %%
# Filter the dates for the year 2022
start_date = "2022-01-01"
end_date = "2022-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2022 = df_sorted.loc[between_two_dates]

print(year_2022)
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 834  Cardano 2022-01-01  1.379984  1.285596  1.358772  1.311360  1.373402e+09
# 833  Cardano 2022-01-02  1.373174  1.307918  1.307918  1.369334  1.221762e+09
# 832  Cardano 2022-01-03  1.387702  1.345197  1.377104  1.377625  9.504997e+08
# 831  Cardano 2022-01-04  1.377621  1.312523  1.377621  1.319542  9.731423e+08
# 830  Cardano 2022-01-05  1.349933  1.298833  1.319444  1.310376  1.164485e+09
# ..       ...        ...       ...       ...       ...       ...           ...
# 474  Cardano 2022-12-27  0.265393  0.257856  0.259202  0.265393  2.789877e+08
# 473  Cardano 2022-12-28  0.266023  0.257103  0.265550  0.260394  2.861189e+08
# 472  Cardano 2022-12-29  0.260982  0.247208  0.260408  0.248249  3.872681e+08
# 471  Cardano 2022-12-30  0.248182  0.240608  0.248182  0.243905  6.032099e+08
# 470  Cardano 2022-12-31  0.245913  0.240191  0.243806  0.245550  8.261448e+08
#
#         Marketcap
# 834  4.213115e+10
# 833  4.195659e+10
# 832  4.290300e+10
# 831  4.247609e+10
# 830  4.163309e+10
# ..            ...
# 474  8.830820e+09
# 473  8.861158e+09
# 472  8.546320e+09
# 471  8.279571e+09
# 470  8.224202e+09
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2022
df_2022 = pd.DataFrame(data=year_2022)
df_2022.head()
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 834  Cardano 2022-01-01  1.379984  1.285596  1.358772  1.311360  1.373402e+09
# 833  Cardano 2022-01-02  1.373174  1.307918  1.307918  1.369334  1.221762e+09
# 832  Cardano 2022-01-03  1.387702  1.345197  1.377104  1.377625  9.504997e+08
# 831  Cardano 2022-01-04  1.377621  1.312523  1.377621  1.319542  9.731423e+08
# 830  Cardano 2022-01-05  1.349933  1.298833  1.319444  1.310376  1.164485e+09
#
#         Marketcap
# 834  4.213115e+10
# 833  4.195659e+10
# 832  4.290300e+10
# 831  4.247609e+10
# 830  4.163309e+10

# %%
# Visualize the Cardano close price for 2022
ax = df_2022.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Cardano in 2022")
# Out:
# Text(0.5, 1.0, 'Close Price of Cardano in 2022')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2022["Log_Returns"] = np.log(df_2022['Close']/df_2022['Close'].shift())
df_2022.head()
# Out:
#         Name       Date      High       Low      Open     Close        Volume  \
# 834  Cardano 2022-01-01  1.379984  1.285596  1.358772  1.311360  1.373402e+09
# 833  Cardano 2022-01-02  1.373174  1.307918  1.307918  1.369334  1.221762e+09
# 832  Cardano 2022-01-03  1.387702  1.345197  1.377104  1.377625  9.504997e+08
# 831  Cardano 2022-01-04  1.377621  1.312523  1.377621  1.319542  9.731423e+08
# 830  Cardano 2022-01-05  1.349933  1.298833  1.319444  1.310376  1.164485e+09
#
#         Marketcap  Log_Returns
# 834  4.213115e+10          NaN
# 833  4.195659e+10     0.043260
# 832  4.290300e+10     0.006036
# 831  4.247609e+10    -0.043076
# 830  4.163309e+10    -0.006971

# %%
# We need the std deviation for the volatility of the stock
# df_2022["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2022 = df_2022["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2022 stock price of Cardano
str_vol_2022 = str(round(volatility_2022, 3)*100)

print(str_vol_2022)
# Out:
# 76.9

# %%
# Visualize the volatility of the 2022 stock price of Cardano

fig, ax = plt.subplots()
df_2022["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2022 Cardano Volatility: " + str_vol_2022 + "%" )
# Out:
# Text(0.5, 1.0, '2022 Cardano Volatility: 76.9%')

# %% [markdown]
# # Examine the volatility for the year 2021

# %%
# Filter the dates for the year 2021
start_date = "2021-01-01"
end_date = "2021-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2021 = df_sorted.loc[between_two_dates]

print(year_2021)
# Out:
#          Name       Date      High       Low      Open     Close  \
# 1199  Cardano 2021-01-01  0.185863  0.176109  0.184359  0.181338
# 1198  Cardano 2021-01-02  0.184898  0.171929  0.181656  0.175499
# 1197  Cardano 2021-01-03  0.183605  0.169996  0.175492  0.176840
# 1196  Cardano 2021-01-04  0.208696  0.174268  0.176670  0.205023
# 1195  Cardano 2021-01-05  0.240448  0.198549  0.205073  0.223508
# ...       ...        ...       ...       ...       ...       ...
# 839   Cardano 2021-12-27  1.466274  1.412291  1.454166  1.455621
# 838   Cardano 2021-12-28  1.588790  1.454449  1.455625  1.515481
# 837   Cardano 2021-12-29  1.534195  1.385593  1.514410  1.409198
# 836   Cardano 2021-12-30  1.431243  1.331293  1.400935  1.331293
# 835   Cardano 2021-12-31  1.372475  1.300723  1.330934  1.358763
#
#             Volume     Marketcap
# 1199  1.160366e+09  5.684168e+09
# 1198  9.044402e+08  5.660996e+09
# 1197  9.662886e+08  5.544039e+09
# 1196  1.546313e+09  5.888745e+09
# 1195  3.062963e+09  6.786336e+09
# ...            ...           ...
# 839   1.132266e+09  4.539880e+10
# 838   1.680166e+09  4.798299e+10
# 837   2.317146e+09  4.597800e+10
# 836   2.074161e+09  4.375028e+10
# 835   1.735135e+09  4.221598e+10
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2021
df_2021 = pd.DataFrame(data=year_2021)
df_2021.head()
# Out:
#          Name       Date      High       Low      Open     Close  \
# 1199  Cardano 2021-01-01  0.185863  0.176109  0.184359  0.181338
# 1198  Cardano 2021-01-02  0.184898  0.171929  0.181656  0.175499
# 1197  Cardano 2021-01-03  0.183605  0.169996  0.175492  0.176840
# 1196  Cardano 2021-01-04  0.208696  0.174268  0.176670  0.205023
# 1195  Cardano 2021-01-05  0.240448  0.198549  0.205073  0.223508
#
#             Volume     Marketcap
# 1199  1.160366e+09  5.684168e+09
# 1198  9.044402e+08  5.660996e+09
# 1197  9.662886e+08  5.544039e+09
# 1196  1.546313e+09  5.888745e+09
# 1195  3.062963e+09  6.786336e+09

# %%
# Visualize the Cardano close price for 2021
ax = df_2021.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Cardano in 2021")
# Out:
# Text(0.5, 1.0, 'Close Price of Cardano in 2021')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2021["Log_Returns"] = np.log(df_2021['Close']/df_2021['Close'].shift())
df_2021.head()
# Out:
#          Name       Date      High       Low      Open     Close  \
# 1199  Cardano 2021-01-01  0.185863  0.176109  0.184359  0.181338
# 1198  Cardano 2021-01-02  0.184898  0.171929  0.181656  0.175499
# 1197  Cardano 2021-01-03  0.183605  0.169996  0.175492  0.176840
# 1196  Cardano 2021-01-04  0.208696  0.174268  0.176670  0.205023
# 1195  Cardano 2021-01-05  0.240448  0.198549  0.205073  0.223508
#
#             Volume     Marketcap  Log_Returns
# 1199  1.160366e+09  5.684168e+09          NaN
# 1198  9.044402e+08  5.660996e+09    -0.032728
# 1197  9.662886e+08  5.544039e+09     0.007609
# 1196  1.546313e+09  5.888745e+09     0.147880
# 1195  3.062963e+09  6.786336e+09     0.086322

# %%
# We need the std deviation for the volatility of the stock
# df_2021["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2021 = df_2021["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2021 stock price of Cardano
str_vol_2021 = str(round(volatility_2021, 2)*100)

print(str_vol_2021)
# Out:
# 105.0

# %%
# Visualize the volatility of the 2021 stock price of Cardano

fig, ax = plt.subplots()
df_2021["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2021 Cardano Volatility: " + str_vol_2021 + "%" )
# Out:
# Text(0.5, 1.0, '2021 Cardano Volatility: 105.0%')

# %%
# Overlay the close price for 2021-2023

x1 = df_2021["Date"]
x2 = df_2022["Date"]
x3 = df_2023["Date"]

a = df_2021["Close"].values
b = df_2022["Close"].values
c = df_2023["Close"].values


plt.plot(x1, a, label= "2021" )
plt.plot(x2, b, label= "2022" )
plt.plot(x3, c, label= "2023" )

plt.title("Close Price of Cardano (2021-2023) ")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.legend()
plt.show()

# %%
# Visualize the volatility percent as a bar chart
# plt.bar(x, height, width, bottom, align)

year = ["2021", "2022", "2023"]
values = [float(str_vol_2021), float(str_vol_2022), float(str_vol_2023)]

colors = ["blue", "orange", "green"]

fig = plt.figure(figsize = (8, 5))
 
# creating the bar plot
plt.bar(x=year, height=values, color=colors, edgecolor='black', width = 0.4, bottom=0)
 
plt.xlabel("Year")
plt.ylabel("Percent Volatility")
plt.title("Annual Percent Volatility of Cardano (2021-2023) ")
plt.show()
