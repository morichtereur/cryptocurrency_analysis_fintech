# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Add in column data as lists

coin_name = ["Binance Coin", "Bitcoin", "Cardano", "Ethereum",
             "Polkadot", "Ripple", "Solana"]

year_2021 = [115.9, 67.0, 105.0, 89.0, 121.0, 121.0, 134.0]

year_2022 = [61.3, 54.1, 76.9, 73.0, 78.0, 71.3, 109.9]

year_2023 = [36.5, 36.1, 55.1, 38.21, 52.44, 65.7, 79.2]

# %%
data = [
    ("Binance Coin", 115.9, 61.3, 36.5),  # Updated values from your list
    ("Bitcoin", 67.0, 54.1, 36.1),         # Updated values from your list
    ("Cardano", 105.0, 76.9, 55.1),        # Updated values from your list
    ("Ethereum", 89.0, 73.0, 38.21),       # Updated values from your list
    ("Polkadot", 121.0, 78.0, 52.44),      # Updated values from your list
    ("Ripple", 121.0, 71.3, 65.7),         # updated values from your list
    ("Solana", 134.0, 109.9, 79.2),        # Updated values from your list
    ("S&P 500", 13.1, 24.3, 13.1),       
]

# %%
# Create summary dataframe of the annual volatility
df = pd.DataFrame(data=data, columns=['coin_name', 'year_2021', 'year_2022', 'year_2023'])
df
# Out:
#       coin_name  year_2021  year_2022  year_2023
# 0  Binance Coin      115.9       61.3      36.50
# 1       Bitcoin       67.0       54.1      36.10
# 2       Cardano      105.0       76.9      55.10
# 3      Ethereum       89.0       73.0      38.21
# 4      Polkadot      121.0       78.0      52.44
# 5        Ripple      121.0       71.3      65.70
# 6        Solana      134.0      109.9      79.20
# 7       S&P 500       13.1       24.3      13.10

# %%
import matplotlib.pyplot as plt

# Data and years for the graph
year = ["2021", "2022", "2023"]
x = year

# Updated data for each coin
a = (115.9, 61.3, 36.5)  # Binance Coin
b = (67.0, 54.1, 36.1)   # Bitcoin
c = (105.0, 76.9, 55.1)  # Cardano
d = (89.0, 73.0, 38.21)  # Ethereum
e = (121.0, 78.0, 52.44) # Polkadot
f = (121.0, 71.3, 65.7)  # Ripple (assuming this is XRP)
g = (134.0, 109.9, 79.2) # Solana
h = (13.1, 24.3, 13.1)   # S&P 500

# Creating the plot
plt.figure(figsize=(12, 12))

plt.plot(x, a, label="Binance Coin")
plt.plot(x, b, label="Bitcoin")
plt.plot(x, c, label="Cardano")
plt.plot(x, d, label="Ethereum")
plt.plot(x, e, label="Polkadot")
plt.plot(x, f, label="Ripple")
plt.plot(x, g, label="Solana")
plt.plot(x, h, label="S&P 500")

# Setting up the x and y ticks, labels, and title
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel("Year", fontsize=16)
plt.ylabel("Annual Percent Volatility", fontsize=16)
plt.title("Annual Percent Volatility (2021-2023)", fontsize=20)

# Adding a legend
plt.legend(fontsize=14)

# Saving the figure
plt.savefig("AnnualPercentVolatilityAllCoins2021-2023.png")

# Display the plot
plt.show()

# %% [markdown]
# ### Most and Least Volatile Each Year:
#
# **2021:**
# - Most Volatile: Solana (134.0%)
# - Least Volatile: Bitcoin (67.0%)
#
# **2022:**
# - Most Volatile: Solana (109.9%)
# - Least Volatile: Bitcoin (54.1%)
#
# **2023:**
# - Most Volatile: Solana (79.2%)
# - Least Volatile: S&P 500 (13.1%)
#
# **Overall (2021-2023):**
# - To determine overall volatility, I'll look at the range (difference between the highest and lowest volatility values) for each coin and the S&P 500 across the three years. A higher range indicates greater volatility over time.
#
# **Volatility Ranges:**
# - Binance Coin:  115.9 − 36.5 = 79.4
# - Bitcoin: 67.0 − 36.1 = 30.9
# - Cardano:  105.0 − 55.1 = 49.9
# - Ethereum: 89.0 − 38.21 = 50.79
# - Polkadot:  121.0 − 52.44 = 68.56
# - Ripple (XRP): 121.0 − 65.7 = 55.3
# - Solana:  134.0 − 79.2 = 54.8
# - S&P 500:  24.3 − 13.1 = 11.2
#
# **Most Volatile Over Time:**
# - Solana (range: 54.8%), closely followed by Binance Coin (range: 79.4%).
#
# **Least Volatile Over Time:**
# - S&P 500 (range: 11.2%), followed by Bitcoin (range: 30.9%).
#
# **Summary:**
# - Solana was consistently the most volatile each year and among the most volatile over the entire period, highlighting its higher risk and potential for significant price changes.
# - Bitcoin and the S&P 500 were among the least volatile, suggesting more stability relative to other cryptocurrencies.
# - The S&P 500, representing a broader market index, shows considerably less volatility compared to individual cryptocurrencies, which reflects its composition of diverse assets reducing individual asset volatility impact.
