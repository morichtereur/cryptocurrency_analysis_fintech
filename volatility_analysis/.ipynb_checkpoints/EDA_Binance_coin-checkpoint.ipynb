# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# %%
# Define the file path. Adjust the username and path to match your local environment.
file_path = '/Users/moritzrichter/Desktop/cryptocurrency_analysis/data/Binance_coin_(BNB)/binance_coin(fiveyears).csv'

# Load the dataset from the specified file path
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to ensure it has loaded correctly
df.head()
# Out:
#            Name        Date      High       Low      Open     Close  \
# 0  Binance_Coin  2024-04-14  598.6123  520.1952  594.8750  556.4911
# 1  Binance_Coin  2024-04-13  626.3403  584.0673  605.9197  597.1419
# 2  Binance_Coin  2024-04-12  615.9983  593.8487  609.2402  605.3837
# 3  Binance_Coin  2024-04-11  610.0007  574.7967  580.4495  609.7329
# 4  Binance_Coin  2024-04-10  589.7062  573.3335  587.7350  581.5226
#
#          Volume     Marketcap
# 0  5.401196e+09  8.672160e+10
# 1  3.588268e+09  9.135172e+10
# 2  3.368401e+09  9.048666e+10
# 3  2.522756e+09  8.827879e+10
# 4  2.230136e+09  8.694344e+10

# %%
# Convert 'Date' to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Sorting the DataFrame by the 'Date' column in ascending order
df_sorted = df.sort_values(by='Date', ascending=True)

print(df_sorted)
# Out:
#               Name       Date        High         Low        Open       Close  \
# 1824  Binance_Coin 2019-04-17   20.142752   18.985843   19.502150   20.055316
# 1823  Binance_Coin 2019-04-18   20.107065   19.688879   20.036108   19.787136
# 1822  Binance_Coin 2019-04-19   22.257706   19.729968   19.790795   22.195677
# 1821  Binance_Coin 2019-04-20   24.884916   21.512709   22.159322   24.541845
# 1820  Binance_Coin 2019-04-21   25.583658   24.070025   24.579824   25.147023
# ...            ...        ...         ...         ...         ...         ...
# 4     Binance_Coin 2024-04-10  589.706200  573.333500  587.735000  581.522600
# 3     Binance_Coin 2024-04-11  610.000700  574.796700  580.449500  609.732900
# 2     Binance_Coin 2024-04-12  615.998300  593.848700  609.240200  605.383700
# 1     Binance_Coin 2024-04-13  626.340300  584.067300  605.919700  597.141900
# 0     Binance_Coin 2024-04-14  598.612300  520.195200  594.875000  556.491100
#
#             Volume     Marketcap
# 1824  1.649055e+08  2.760849e+09
# 1823  1.558340e+08  2.801093e+09
# 1822  2.988409e+08  2.980958e+09
# 1821  3.856008e+08  3.241708e+09
# 1820  3.945320e+08  3.503405e+09
# ...            ...           ...
# 4     2.230136e+09  8.694344e+10
# 3     2.522756e+09  8.827879e+10
# 2     3.368401e+09  9.048666e+10
# 1     3.588268e+09  9.135172e+10
# 0     5.401196e+09  8.672160e+10
#
# [1825 rows x 8 columns]

# %%
df_sorted.tail()
# Out:
#            Name       Date      High       Low      Open     Close  \
# 4  Binance_Coin 2024-04-10  589.7062  573.3335  587.7350  581.5226
# 3  Binance_Coin 2024-04-11  610.0007  574.7967  580.4495  609.7329
# 2  Binance_Coin 2024-04-12  615.9983  593.8487  609.2402  605.3837
# 1  Binance_Coin 2024-04-13  626.3403  584.0673  605.9197  597.1419
# 0  Binance_Coin 2024-04-14  598.6123  520.1952  594.8750  556.4911
#
#          Volume     Marketcap
# 4  2.230136e+09  8.694344e+10
# 3  2.522756e+09  8.827879e+10
# 2  3.368401e+09  9.048666e+10
# 1  3.588268e+09  9.135172e+10
# 0  5.401196e+09  8.672160e+10

# %%
df_sorted.shape
# Out:
# (1825, 8)

# %%
# Check for null values in the Close column
df_sorted["Close"].isnull().values.any()
# Out:
# False

# %%
# Visualize the close price over time
ax = df_sorted.plot(x='Date', y='Close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Binance_coin")
# Out:
# Text(0.5, 1.0, 'Close Price of Binance_coin')

# %% [markdown]
# # Examine the volatility for the year 2023

# %%
# Filter the dates for the year 2023
start_date = "2023-01-01"
end_date = "2023-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2023 = df_sorted.loc[between_two_dates]

print(year_2023)
# Out:
#              Name       Date        High         Low        Open       Close  \
# 469  Binance_Coin 2023-01-01  248.727000  246.225827  247.193270  247.661000
# 468  Binance_Coin 2023-01-02  247.807471  244.917900  247.567600  245.531711
# 467  Binance_Coin 2023-01-03  248.911100  243.160344  245.816953  246.491466
# 466  Binance_Coin 2023-01-04  247.885850  245.894666  246.511103  247.362703
# 465  Binance_Coin 2023-01-05  262.042791  246.940478  247.374300  260.678727
# ..            ...        ...         ...         ...         ...         ...
# 109  Binance_Coin 2023-12-27  302.040800  265.083000  266.822900  297.540100
# 108  Binance_Coin 2023-12-28  322.483900  286.290500  296.713900  322.483900
# 107  Binance_Coin 2023-12-29  337.071200  319.920700  319.920700  323.235900
# 106  Binance_Coin 2023-12-30  325.277700  309.345300  323.487100  313.247400
# 105  Binance_Coin 2023-12-31  319.902800  313.301100  313.433100  317.108900
#
#            Volume     Marketcap
# 469  8.706102e+08  3.958618e+10
# 468  8.140008e+08  3.938124e+10
# 467  1.006569e+09  3.949343e+10
# 466  9.075007e+08  3.948544e+10
# 465  1.473831e+09  4.098667e+10
# ..            ...           ...
# 109  2.330278e+09  4.305704e+10
# 108  3.871479e+09  4.598150e+10
# 107  3.977370e+09  4.967837e+10
# 106  3.095120e+09  4.799597e+10
# 105  1.665400e+09  4.803148e+10
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2023
df_2023 = pd.DataFrame(data=year_2023)
df_2023.head()
# Out:
#              Name       Date        High         Low        Open       Close  \
# 469  Binance_Coin 2023-01-01  248.727000  246.225827  247.193270  247.661000
# 468  Binance_Coin 2023-01-02  247.807471  244.917900  247.567600  245.531711
# 467  Binance_Coin 2023-01-03  248.911100  243.160344  245.816953  246.491466
# 466  Binance_Coin 2023-01-04  247.885850  245.894666  246.511103  247.362703
# 465  Binance_Coin 2023-01-05  262.042791  246.940478  247.374300  260.678727
#
#            Volume     Marketcap
# 469  8.706102e+08  3.958618e+10
# 468  8.140008e+08  3.938124e+10
# 467  1.006569e+09  3.949343e+10
# 466  9.075007e+08  3.948544e+10
# 465  1.473831e+09  4.098667e+10

# %%
# Visualize the Binance_coin close price for 2023
ax = df_2023.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Binance_coin in 2023")
# Out:
# Text(0.5, 1.0, 'Close Price of Binance_coin in 2023')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2023["Log_Returns"] = np.log(df_2023['Close']/df_2023['Close'].shift())
df_2023.head()
# Out:
#              Name       Date        High         Low        Open       Close  \
# 469  Binance_Coin 2023-01-01  248.727000  246.225827  247.193270  247.661000
# 468  Binance_Coin 2023-01-02  247.807471  244.917900  247.567600  245.531711
# 467  Binance_Coin 2023-01-03  248.911100  243.160344  245.816953  246.491466
# 466  Binance_Coin 2023-01-04  247.885850  245.894666  246.511103  247.362703
# 465  Binance_Coin 2023-01-05  262.042791  246.940478  247.374300  260.678727
#
#            Volume     Marketcap  Log_Returns
# 469  8.706102e+08  3.958618e+10          NaN
# 468  8.140008e+08  3.938124e+10    -0.008635
# 467  1.006569e+09  3.949343e+10     0.003901
# 466  9.075007e+08  3.948544e+10     0.003528
# 465  1.473831e+09  4.098667e+10     0.052433

# %%
# We need the std deviation for the volatility of the stock
# df_2023["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2023 = df_2023["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2023 stock price of Binance_coin
str_vol_2023 = str(round(volatility_2023, 4)*100)

print(str_vol_2023)
# Out:
# 36.53

# %%
# Visualize the volatility of the 2023 stock price of Binance_coin

fig, ax = plt.subplots()
df_2023["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2023 Binance_coin Volatility: " + str_vol_2023 + "%" )
# Out:
# Text(0.5, 1.0, '2023 Binance_coin Volatility: 36.53%')

# %% [markdown]
# # Examine the volatility for the year 2022

# %%
# Filter the dates for the year 2022
start_date = "2022-01-01"
end_date = "2022-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2022 = df_sorted.loc[between_two_dates]

print(year_2022)
# Out:
#              Name       Date        High         Low        Open       Close  \
# 834  Binance_Coin 2022-01-01  527.728800  507.924156  518.727500  512.308250
# 833  Binance_Coin 2022-01-02  526.796700  511.632563  511.632563  526.771500
# 832  Binance_Coin 2022-01-03  532.772200  519.259400  527.424900  531.545800
# 831  Binance_Coin 2022-01-04  532.199100  510.961042  531.405300  512.538400
# 830  Binance_Coin 2022-01-05  519.581500  503.801139  512.117200  507.786505
# ..            ...        ...         ...         ...         ...         ...
# 474  Binance_Coin 2022-12-27  245.789064  243.337175  244.529347  245.157793
# 473  Binance_Coin 2022-12-28  247.653375  243.654500  245.417019  247.498974
# 472  Binance_Coin 2022-12-29  247.712200  243.451800  247.522887  244.962742
# 471  Binance_Coin 2022-12-30  247.742800  244.585700  245.155562  247.445745
# 470  Binance_Coin 2022-12-31  247.594205  244.366500  247.374451  246.972212
#
#            Volume     Marketcap
# 834  2.342051e+09  8.626745e+10
# 833  2.178449e+09  8.652887e+10
# 832  1.748154e+09  8.765888e+10
# 831  1.873369e+09  8.739738e+10
# 830  2.684612e+09  8.538952e+10
# ..            ...           ...
# 474  9.149035e+08  3.907836e+10
# 473  9.550664e+08  3.924146e+10
# 472  1.285641e+09  3.918695e+10
# 471  1.143998e+09  3.942245e+10
# 470  9.967659e+08  3.934526e+10
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2022
df_2022 = pd.DataFrame(data=year_2022)
df_2022.head()
# Out:
#              Name       Date      High         Low        Open       Close  \
# 834  Binance_Coin 2022-01-01  527.7288  507.924156  518.727500  512.308250
# 833  Binance_Coin 2022-01-02  526.7967  511.632563  511.632563  526.771500
# 832  Binance_Coin 2022-01-03  532.7722  519.259400  527.424900  531.545800
# 831  Binance_Coin 2022-01-04  532.1991  510.961042  531.405300  512.538400
# 830  Binance_Coin 2022-01-05  519.5815  503.801139  512.117200  507.786505
#
#            Volume     Marketcap
# 834  2.342051e+09  8.626745e+10
# 833  2.178449e+09  8.652887e+10
# 832  1.748154e+09  8.765888e+10
# 831  1.873369e+09  8.739738e+10
# 830  2.684612e+09  8.538952e+10

# %%
# Visualize the Solana close price for 2022
ax = df_2022.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Binance_coin in 2022")
# Out:
# Text(0.5, 1.0, 'Close Price of Binance_coin in 2022')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2022["Log_Returns"] = np.log(df_2022['Close']/df_2022['Close'].shift())
df_2022.head()
# Out:
#              Name       Date      High         Low        Open       Close  \
# 834  Binance_Coin 2022-01-01  527.7288  507.924156  518.727500  512.308250
# 833  Binance_Coin 2022-01-02  526.7967  511.632563  511.632563  526.771500
# 832  Binance_Coin 2022-01-03  532.7722  519.259400  527.424900  531.545800
# 831  Binance_Coin 2022-01-04  532.1991  510.961042  531.405300  512.538400
# 830  Binance_Coin 2022-01-05  519.5815  503.801139  512.117200  507.786505
#
#            Volume     Marketcap  Log_Returns
# 834  2.342051e+09  8.626745e+10          NaN
# 833  2.178449e+09  8.652887e+10     0.027840
# 832  1.748154e+09  8.765888e+10     0.009022
# 831  1.873369e+09  8.739738e+10    -0.036414
# 830  2.684612e+09  8.538952e+10    -0.009315

# %%
# We need the std deviation for the volatility of the stock
# df_2022["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2022 = df_2022["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2022 stock price of Binance_coin
str_vol_2022 = str(round(volatility_2022, 3)*100)

print(str_vol_2022)
# Out:
# 61.3

# %%
# Visualize the volatility of the 2022 stock price of Binance_coin

fig, ax = plt.subplots()
df_2022["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2022 Binance_coin Volatility: " + str_vol_2022 + "%" )
# Out:
# Text(0.5, 1.0, '2022 Binance_coin Volatility: 61.3%')

# %% [markdown]
# # Examine the volatility for the year 2021

# %%
# Filter the dates for the year 2021
start_date = "2021-01-01"
end_date = "2021-12-31"

after_start_date = df_sorted["Date"] >= start_date
before_end_date = df_sorted["Date"] <= end_date
between_two_dates = after_start_date & before_end_date
year_2021 = df_sorted.loc[between_two_dates]

print(year_2021)
# Out:
#               Name       Date        High         Low        Open       Close  \
# 1199  Binance_Coin 2021-01-01   38.160678   36.809970   38.160678   37.377063
# 1198  Binance_Coin 2021-01-02   38.950960   37.069237   37.385192   37.900542
# 1197  Binance_Coin 2021-01-03   38.741357   36.967081   37.771549   38.044762
# 1196  Binance_Coin 2021-01-04   41.343945   37.902526   38.017135   40.931103
# 1195  Binance_Coin 2021-01-05   42.904021   38.274629   40.979574   40.752928
# ...            ...        ...         ...         ...         ...         ...
# 839   Binance_Coin 2021-12-27  549.309802  537.957200  547.979547  547.356342
# 838   Binance_Coin 2021-12-28  570.499551  544.183200  547.077872  563.266494
# 837   Binance_Coin 2021-12-29  563.057528  530.742284  563.057528  535.630600
# 836   Binance_Coin 2021-12-30  540.033970  512.925364  534.384300  513.832485
# 835   Binance_Coin 2021-12-31  527.479764  510.730996  514.281901  518.750800
#
#             Volume     Marketcap
# 1199  9.476995e+08  5.393737e+09
# 1198  9.325444e+08  5.475451e+09
# 1197  1.006033e+09  5.440829e+09
# 1196  1.353045e+09  5.678544e+09
# 1195  1.924814e+09  5.822111e+09
# ...            ...           ...
# 839   1.921339e+09  9.076946e+10
# 838   2.114584e+09  9.245729e+10
# 837   3.436874e+09  9.105913e+10
# 836   2.659533e+09  8.849488e+10
# 835   2.556834e+09  8.661236e+10
#
# [365 rows x 8 columns]

# %%
# Create a new dataframe showing only 2021
df_2021 = pd.DataFrame(data=year_2021)
df_2021.head()
# Out:
#               Name       Date       High        Low       Open      Close  \
# 1199  Binance_Coin 2021-01-01  38.160678  36.809970  38.160678  37.377063
# 1198  Binance_Coin 2021-01-02  38.950960  37.069237  37.385192  37.900542
# 1197  Binance_Coin 2021-01-03  38.741357  36.967081  37.771549  38.044762
# 1196  Binance_Coin 2021-01-04  41.343945  37.902526  38.017135  40.931103
# 1195  Binance_Coin 2021-01-05  42.904021  38.274629  40.979574  40.752928
#
#             Volume     Marketcap
# 1199  9.476995e+08  5.393737e+09
# 1198  9.325444e+08  5.475451e+09
# 1197  1.006033e+09  5.440829e+09
# 1196  1.353045e+09  5.678544e+09
# 1195  1.924814e+09  5.822111e+09

# %%
# Visualize the Binance_coin close price for 2021
ax = df_2021.plot(x='Date', y='Close');
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
ax.set_title("Close Price of Binance_coin in 2021")
# Out:
# Text(0.5, 1.0, 'Close Price of Binance_coin in 2021')

# %%
# Add a column called "Log_Returns" with the daily log return of the Close price
df_2021["Log_Returns"] = np.log(df_2021['Close']/df_2021['Close'].shift())
df_2021.head()
# Out:
#               Name       Date       High        Low       Open      Close  \
# 1199  Binance_Coin 2021-01-01  38.160678  36.809970  38.160678  37.377063
# 1198  Binance_Coin 2021-01-02  38.950960  37.069237  37.385192  37.900542
# 1197  Binance_Coin 2021-01-03  38.741357  36.967081  37.771549  38.044762
# 1196  Binance_Coin 2021-01-04  41.343945  37.902526  38.017135  40.931103
# 1195  Binance_Coin 2021-01-05  42.904021  38.274629  40.979574  40.752928
#
#             Volume     Marketcap  Log_Returns
# 1199  9.476995e+08  5.393737e+09          NaN
# 1198  9.325444e+08  5.475451e+09     0.013908
# 1197  1.006033e+09  5.440829e+09     0.003798
# 1196  1.353045e+09  5.678544e+09     0.073127
# 1195  1.924814e+09  5.822111e+09    -0.004363

# %%
# We need the std deviation for the volatility of the stock
# df_2021["Log_Returns"].std()

# Volatility is defined as the annualized standard deviation. There are ~253 trading days per year. Square root = **.5
volatility_2021 = df_2021["Log_Returns"].std()*253**.5

# %%
# Calculate the volatility of the 2021 stock price of Binance_coin
str_vol_2021 = str(round(volatility_2021, 2)*100)

print(str_vol_2021)
# Out:
# 115.99999999999999

# %%
# Visualize the volatility of the 2021 stock price of Binance_coin

fig, ax = plt.subplots()
df_2021["Log_Returns"].hist(ax=ax, bins=50, alpha=0.6, color="b")
ax.set_xlabel("Log Return")
ax.set_ylabel("Frequency of Log Return")
ax.set_title("2021 Binance_coin Volatility: " + str_vol_2021 + "%" )
# Out:
# Text(0.5, 1.0, '2021 Binance_coin Volatility: 115.99999999999999%')

# %%
# Overlay the close price for 2021-2023

x1 = df_2021["Date"]
x2 = df_2022["Date"]
x3 = df_2023["Date"]

a = df_2021["Close"].values
b = df_2022["Close"].values
c = df_2023["Close"].values


plt.plot(x1, a, label= "2021" )
plt.plot(x2, b, label= "2022" )
plt.plot(x3, c, label= "2023" )

plt.title("Close Price of Binance_coin (2021-2023) ")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.legend()
plt.show()

# %%
# Visualize the volatility percent as a bar chart
# plt.bar(x, height, width, bottom, align)

year = ["2021", "2022", "2023"]
values = [float(str_vol_2021), float(str_vol_2022), float(str_vol_2023)]

colors = ["blue", "orange", "green"]

fig = plt.figure(figsize = (8, 5))
 
# creating the bar plot
plt.bar(x=year, height=values, color=colors, edgecolor='black', width = 0.4, bottom=0)
 
plt.xlabel("Year")
plt.ylabel("Percent Volatility")
plt.title("Annual Percent Volatility of Binance_coin (2021-2023) ")
plt.show()
