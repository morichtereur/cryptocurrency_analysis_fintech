# %%
import matplotlib.pyplot as plt

# Data
cryptos = ['BTC', 'ETH', 'BNB', 'ADA', 'SOL', 'XRP', 'DOT']
precision_rf = [0.5009225092250923, 0.5052631578947369, 0.5114638447971781, 0.49759615384615385, 0.5145631067961165, 0.5167910447761194, 0.4842105263157895]
precision_xgb = [0.5257548845470693, 0.5238095238095238, 0.5342960288808665, 0.5435897435897435, 0.5376344086021505, 0.5181159420289855, 0.5368421052631579]
precision_trends = [0.5882352941176471, 0.5450121654501217, 0.5425531914893617, 0.5769230769230769, 0.546875, 0.5333333333333333, 0.6129032258064516]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(cryptos, precision_rf, marker='o', label='RandomForestClassifier')
plt.plot(cryptos, precision_xgb, marker='o', label='XGBoost model')
plt.plot(cryptos, precision_trends, marker='o', label='Improving precision with trends')

# Add labels and title
plt.xlabel('Cryptocurrency')
plt.ylabel('Precision Score')
plt.title('Precision Scores for Different Models and Cryptocurrencies')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
cryptos = ['BTC', 'ETH', 'BNB', 'ADA', 'SOL', 'XRP', 'DOT']
precision_rf = [0.5009225092250923, 0.5052631578947369, 0.5114638447971781, 0.49759615384615385, 0.5145631067961165, 0.5167910447761194, 0.4842105263157895]
precision_xgb = [0.5257548845470693, 0.5238095238095238, 0.5342960288808665, 0.5435897435897435, 0.5376344086021505, 0.5181159420289855, 0.5368421052631579]
precision_trends = [0.5882352941176471, 0.5450121654501217, 0.5425531914893617, 0.5769230769230769, 0.546875, 0.5333333333333333, 0.6129032258064516]

# Plot
plt.figure(figsize=(10, 6))

# Plot each line
plt.plot(cryptos, precision_rf, marker='o', label='RandomForestClassifier')
plt.plot(cryptos, precision_xgb, marker='o', label='XGBoost model')
plt.plot(cryptos, precision_trends, marker='o', label='Improving precision with trends')

# Add labels and title
plt.xlabel('Cryptocurrency')
plt.ylabel('Precision Score')
plt.title('Precision Scores for Different Models and Cryptocurrencies')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add grid lines for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Data
data = {
    'Cryptocurrency': cryptos,
    'Precision_RF': precision_rf,
    'Precision_XGB': precision_xgb,
    'Precision_Trends': precision_trends
}

# Create DataFrame
df = pd.DataFrame(data)

# Print DataFrame
print(df)
# Out:
#   Cryptocurrency  Precision_RF  Precision_XGB  Precision_Trends
# 0            BTC      0.500923       0.525755          0.588235
# 1            ETH      0.505263       0.523810          0.545012
# 2            BNB      0.511464       0.534296          0.542553
# 3            ADA      0.497596       0.543590          0.576923
# 4            SOL      0.514563       0.537634          0.546875
# 5            XRP      0.516791       0.518116          0.533333
# 6            DOT      0.484211       0.536842          0.612903
